# %%
"""Логирование уроков."""

# %% [markdown]
# 06/04
#
# 1) небольшой рассказ о себе в meet в телеграмме
# 2) зарегистрировалась и оформила github + отправила ссылку в чат
# 3) зарегистрировалась и оформила kaggle, получила статус contributor + отправила ссылку в чат
# 4) зарегистрировалась в ods.ai + отправила ссылку в чат
# 5) скачала и установила GitHub Desktop
# 6) скачала и установила cursor
# 7) скачала и установила VS code
# 8) установила необходимые плагины + активировала русский язык в VS CODE и cursor
# 9) скачала и установила Python, GIT for macos, Conda
# 10) оформила джамборд для учебы на canva.com
# 11) скачала репозиторий, присоединилась к команде
# 12) создала fork и клонировала репозиторий на локальный компьютер
# 13) ввела все необходимые команды и прислала скриншот терминала в чат
# 14) посмотрела видео про процесс принятия и отправки коммитов и работе с линтером и создала файл log.ipynb
